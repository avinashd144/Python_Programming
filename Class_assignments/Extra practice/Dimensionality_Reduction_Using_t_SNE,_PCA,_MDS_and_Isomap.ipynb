# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.random.seed(42)

# %%
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE

# %%
def plot_mapping(X, y):
  figure(figsize=(8,6))
  colors=cm.tab10(np.linspace(0,1,9))
  for i in range(9):
    selector=y==i
    Xs=X[selector, :]
    scatter(Xs[:,0], Xs[:,1], label=str(i),
            color=colors[i], s=60, alpha=0.75, edgecolor='k')
    legend()
    axis('off')

# %%
digits=load_digits()
X=digits.data
y=digits.target

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
print(X.shape)
# Out:
# (1797, 64)

# %%
X

# %%
figure(figsize=(10,5))
imshow(X[:200].reshape(10,20,8,8).transpose(0,2,1,3).reshape(80,160))
grid(False)
xticks([])
yticks([])
gray()

# %% [markdown]
# **t-SNE**

# %%
tsne=TSNE(random_state=101)
X_tsne=tsne.fit_transform(digits.data)

# %%
X_tsne
# Out:
# array([[ -2.9060667, -53.966824 ],
#        [ 10.571158 ,  11.5219965],
#        [-13.350177 ,  18.723854 ],
#        ...,
#        [ -5.7808867,  10.558315 ],
#        [-21.469706 , -15.210739 ],
#        [-14.109248 ,   6.876183 ]], dtype=float32)

# %%
print(X.shape)
print(X_tsne.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
plot_mapping(X_tsne, digits.target)

# %% [markdown]
# **PCA**

# %%
from sklearn.decomposition import PCA

pca=PCA(2)
X_pca=pca.fit_transform(digits.data)

# %%
X_pca
# Out:
# array([[ -1.25946645, -21.27488348],
#        [  7.9576113 ,  20.76869896],
#        [  6.99192297,   9.95598641],
#        ...,
#        [ 10.8012837 ,   6.96025223],
#        [ -4.87210009, -12.42395362],
#        [ -0.34438963,  -6.36554919]])

# %%
plot_mapping(X_pca, digits.target)

# %% [markdown]
# **MDS**

# %%
from sklearn.manifold import MDS
mds=MDS(2)

X_mds=mds.fit_transform(digits.data)

# %%
X_mds
# Out:
# array([[-11.42869858, -26.77574526],
#        [ 25.1159327 ,  14.76546111],
#        [ 30.86325215,   8.70311982],
#        ...,
#        [ 18.57302873,  -0.0932611 ],
#        [-11.51068986, -16.41661307],
#        [ -0.93982514, -10.08465056]])

# %%
plot_mapping(X_mds, digits.target)

# %% [markdown]
# **Isomap**

# %%
from sklearn.manifold import Isomap

iso=Isomap()
X_iso=iso.fit_transform(digits.data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_isomap.py:383: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_index.py:108: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
X_iso
# Out:
# array([[163.00637036,  27.23090004],
#        [-46.07580038,  48.77633869],
#        [-97.65710826,  21.77394657],
#        ...,
#        [-50.17322316, -24.63912504],
#        [ -1.55404775, -72.15423108],
#        [-10.15067642, -37.00028856]])

# %%
plot_mapping(X_iso, digits.target)
